# %% [markdown]
# # Directed hypergraph statistics (UNPROCESSED)

# %%
import pickle
import numpy as np
import networkx as nx
import xgi
import os
import matplotlib.pyplot as plt
from itertools import product, permutations
from collections import defaultdict

from useful_functions import *

# %% [markdown]
# ## Chemical reactions

# %% [markdown]
# ### Astrochem

# %%
with open('ParsedHyperedges/Chemical/astrochem.pkl', 'rb') as f:
    astrochem_data = pickle.load(f)

# %%
H = xgi.DiHypergraph(astrochem_data)
#H.edges.dimembers()

# %% [markdown]
# IMPORTANT: Reactions such as H + H -> H2 require directed hyperedges with multiset collections (as in the Uplift paper with the multiply added auxiliary node). In XGI this is not contemplated.

# %%
N, E, in_dict, out_dict, size_dict = hypergraph_statistics(astrochem_data)

# %%
N, E, in_dict, out_dict, size_dict
# Out:
# (482,
#  6046,
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 5618, 1: 428}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {1: 157, 2: 4500, 3: 1321, 4: 68}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {(2, 1): 155,
#               (2, 2): 4110,
#               (2, 3): 1288,
#               (1, 2): 390,
#               (1, 3): 33,
#               (1, 4): 3,
#               (1, 1): 2,
#               (2, 4): 65}))

# %%
fig, ax  = plt.subplots(1,3, figsize=(15,5))

ax[0].bar(in_dict.keys(), in_dict.values())

ax[1].bar(out_dict.keys(), out_dict.values())

ax[2].bar([str(size) for size in size_dict.keys()], size_dict.values())

ax[2].set_xticks(ax[2].get_xticks())
ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=90, ha='right')

plt.show()

# %% [markdown]
# ### Pathways

# %% [markdown]
# #### PID

# %%
with open('ParsedHyperedges/Chemical/pid.pkl', 'rb') as f:
    pid_data = pickle.load(f)

# %%
import xgi
H = xgi.DiHypergraph(pid_data)
#H.edges.dimembers()

# %% [markdown]
# IMPORTANT: Reactions such as H + H -> H2 require directed hyperedges with multiset collections (as in the Uplift paper with the multiply added auxiliary node). In XGI this is not contemplated.

# %%
N, E, in_dict, out_dict, size_dict = hypergraph_statistics(pid_data)

# %%
N, E, in_dict, out_dict, size_dict
# Out:
# (9009,
#  8014,
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 3972,
#               3: 1229,
#               1: 2518,
#               5: 55,
#               4: 210,
#               10: 1,
#               7: 4,
#               6: 23,
#               8: 2}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {1: 7103, 2: 760, 4: 27, 5: 9, 3: 115}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {(2, 1): 3673,
#               (3, 1): 784,
#               (1, 1): 2474,
#               (3, 2): 398,
#               (2, 2): 250,
#               (5, 4): 1,
#               (4, 2): 54,
#               (3, 4): 15,
#               (10, 2): 1,
#               (2, 5): 4,
#               (4, 1): 128,
#               (3, 3): 31,
#               (4, 3): 21,
#               (5, 1): 31,
#               (7, 2): 1,
#               (2, 3): 40,
#               (1, 3): 8,
#               (5, 2): 16,
#               (2, 4): 5,
#               (6, 2): 7,
#               (1, 2): 33,
#               (6, 1): 8,
#               (4, 5): 3,
#               (5, 3): 7,
#               (6, 3): 8,
#               (8, 1): 2,
#               (1, 4): 2,
#               (4, 4): 4,
#               (7, 1): 3,
#               (1, 5): 1,
#               (3, 5): 1}))

# %%
fig, ax  = plt.subplots(1,3, figsize=(15,5))

ax[0].bar(in_dict.keys(), in_dict.values())

ax[1].bar(out_dict.keys(), out_dict.values())

ax[2].bar([str(size) for size in size_dict.keys()], size_dict.values())

ax[2].set_xticks(ax[2].get_xticks())
ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=90, ha='right')

plt.show()

# %% [markdown]
# #### Reactome

# %%
with open('ParsedHyperedges/Chemical/reactome.pkl', 'rb') as f:
    reactome_data = pickle.load(f)

# %%
import xgi
H = xgi.DiHypergraph(reactome_data)
#H.edges.dimembers()

# %% [markdown]
# IMPORTANT: Reactions such as H + H -> H2 require directed hyperedges with multiset collections (as in the Uplift paper with the multiply added auxiliary node). In XGI this is not contemplated.

# %%
N, E, in_dict, out_dict, size_dict = hypergraph_statistics(reactome_data)

# %%
N, E, in_dict, out_dict, size_dict
# Out:
# (20458,
#  11802,
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 6086,
#               1: 1490,
#               3: 3179,
#               10: 6,
#               4: 681,
#               5: 243,
#               6: 55,
#               9: 10,
#               8: 14,
#               7: 23,
#               23: 1,
#               18: 2,
#               11: 3,
#               13: 2,
#               12: 3,
#               14: 1,
#               26: 1,
#               15: 1,
#               19: 1}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 3860,
#               1: 6740,
#               3: 847,
#               4: 204,
#               5: 71,
#               6: 17,
#               8: 12,
#               9: 9,
#               7: 23,
#               11: 4,
#               13: 1,
#               17: 1,
#               15: 2,
#               28: 1,
#               20: 3,
#               16: 3,
#               24: 1,
#               25: 1,
#               14: 1,
#               12: 1}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {(2, 2): 1159,
#               (1, 1): 999,
#               (3, 2): 2145,
#               (2, 1): 4708,
#               (3, 3): 241,
#               (3, 1): 729,
#               (10, 1): 6,
#               (4, 2): 193,
#               (2, 3): 142,
#               (5, 3): 130,
#               (3, 4): 28,
#               (5, 1): 61,
#               (2, 4): 41,
#               (4, 1): 164,
#               (4, 3): 257,
#               (1, 2): 337,
#               (5, 4): 33,
#               (6, 4): 4,
#               (9, 1): 8,
#               (1, 5): 20,
#               (5, 2): 12,
#               (4, 4): 54,
#               (1, 6): 6,
#               (1, 3): 63,
#               (8, 1): 11,
#               (7, 3): 3,
#               (3, 5): 20,
#               (1, 8): 2,
#               (2, 5): 14,
#               (6, 1): 29,
#               (3, 9): 3,
#               (1, 4): 43,
#               (2, 9): 1,
#               (4, 7): 3,
#               (1, 7): 10,
#               (7, 1): 14,
#               (1, 9): 4,
#               (6, 2): 9,
#               (3, 7): 3,
#               (2, 6): 5,
#               (2, 11): 1,
#               (2, 8): 4,
#               (23, 1): 1,
#               (2, 7): 6,
#               (1, 13): 1,
#               (3, 6): 2,
#               (2, 17): 1,
#               (2, 15): 2,
#               (3, 28): 1,
#               (7, 9): 1,
#               (8, 8): 1,
#               (5, 5): 6,
#               (4, 5): 7,
#               (7, 5): 2,
#               (18, 1): 2,
#               (3, 20): 1,
#               (11, 1): 3,
#               (13, 2): 1,
#               (4, 16): 2,
#               (1, 24): 1,
#               (6, 11): 1,
#               (7, 7): 1,
#               (6, 6): 2,
#               (6, 3): 9,
#               (12, 2): 2,
#               (2, 25): 1,
#               (1, 14): 1,
#               (13, 1): 1,
#               (3, 11): 1,
#               (3, 8): 4,
#               (12, 5): 1,
#               (14, 1): 1,
#               (4, 8): 1,
#               (3, 16): 1,
#               (26, 1): 1,
#               (7, 2): 1,
#               (8, 2): 1,
#               (9, 3): 2,
#               (5, 6): 1,
#               (15, 1): 1,
#               (7, 4): 1,
#               (8, 6): 1,
#               (1, 12): 1,
#               (6, 5): 1,
#               (19, 1): 1,
#               (1, 11): 1,
#               (1, 20): 1,
#               (2, 20): 1}))

# %%
fig, ax  = plt.subplots(1,3, figsize=(15,5))

ax[0].bar(in_dict.keys(), in_dict.values())

ax[1].bar(out_dict.keys(), out_dict.values())

ax[2].bar([str(size) for size in size_dict.keys()], size_dict.values())

ax[2].set_xticks(ax[2].get_xticks())
ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=90, ha='right')

plt.show()

# %% [markdown]
# ### KIDA

# %%
with open('ParsedHyperedges/Chemical/KIDA_termolecular.pkl', 'rb') as f:
    KIDA_dataT = pickle.load(f)
    
with open('ParsedHyperedges/Chemical/KIDA_unibimolecular.pkl', 'rb') as f:
    KIDA_dataU = pickle.load(f)
    
with open('ParsedHyperedges/Chemical/KIDA_surface.pkl', 'rb') as f:
    KIDA_dataS = pickle.load(f)

with open('ParsedHyperedges/Chemical/KIDA_uva.pkl', 'rb') as f:
    KIDA_dataV = pickle.load(f)

# %%
#H = xgi.DiHypergraph(KIDA_data)
#H.edges.dimembers()

# %% [markdown]
# IMPORTANT: Reactions such as H + H -> H2 require directed hyperedges with multiset collections (as in the Uplift paper with the multiply added auxiliary node). In XGI this is not contemplated.

# %%
NT, ET, in_dictT, out_dictT, size_dictT = hypergraph_statistics(KIDA_dataT)
NT, ET, in_dictT, out_dictT, size_dictT
# Out:
# (67,
#  86,
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {3: 84, 4: 1, 2: 1}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 78, 3: 7, 1: 1}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {(3, 2): 77, (3, 3): 7, (4, 1): 1, (2, 2): 1}))

# %%
NU, EU, in_dictU, out_dictU, size_dictU = hypergraph_statistics(KIDA_dataU)
NU, EU, in_dictU, out_dictU, size_dictU
# Out:
# (527,
#  7748,
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 7748}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 6740, 3: 865, 1: 54, 4: 89}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {(2, 2): 6740, (2, 3): 865, (2, 1): 54, (2, 4): 89}))

# %%
NS, ES, in_dictS, out_dictS, size_dictS = hypergraph_statistics(KIDA_dataS)
NS, ES, in_dictS, out_dictS, size_dictS
# Out:
# (145,
#  393,
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 393}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {1: 258, 2: 134, 3: 1}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {(2, 1): 258, (2, 2): 134, (2, 3): 1}))

# %%
NV, EV, in_dictV, out_dictV, size_dictV = hypergraph_statistics(KIDA_dataV)
NV, EV, in_dictV, out_dictV, size_dictV
# Out:
# (492,
#  7505,
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 7504, 1: 1}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 5886, 3: 1494, 4: 115, 1: 10}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {(2, 2): 5886, (2, 3): 1494, (2, 4): 115, (2, 1): 9, (1, 1): 1}))

# %%
fig, ax  = plt.subplots(1,3, figsize=(15,5))

ax[0].bar(in_dictT.keys(), in_dictT.values())
ax[0].bar(in_dictS.keys(), in_dictS.values())

ax[1].bar(out_dictT.keys(), out_dictT.values())
ax[1].bar(out_dictS.keys(), out_dictS.values())

ax[2].bar([str(size) for size in size_dictT.keys()], size_dictT.values())
ax[2].bar([str(size) for size in size_dictS.keys()], size_dictS.values())

ax[2].set_xticks(ax[2].get_xticks())
ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=90, ha='right')

plt.show()

# %%
fig, ax  = plt.subplots(1,3, figsize=(15,5))

ax[0].bar(in_dictU.keys(), in_dictU.values())
ax[0].bar(in_dictV.keys(), in_dictV.values())

ax[1].bar(out_dictU.keys(), out_dictU.values())
ax[1].bar(out_dictV.keys(), out_dictV.values())

ax[2].bar([str(size) for size in size_dictU.keys()], size_dictU.values())
ax[2].bar([str(size) for size in size_dictV.keys()], size_dictV.values())

ax[2].set_xticks(ax[2].get_xticks())
ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=90, ha='right')

plt.show()

# %% [markdown]
# ### Reaction Template Generator

# %%
with open('ParsedHyperedges/Chemical/ReactionTemplate.pkl', 'rb') as f:
    RT_data = pickle.load(f)

# %%
H = xgi.DiHypergraph(RT_data)
#H.edges.dimembers()

# %% [markdown]
# IMPORTANT: Reactions such as H + H -> H2 require directed hyperedges with multiset collections (as in the Uplift paper with the multiply added auxiliary node). In XGI this is not contemplated.

# %%
N, E, in_dict, out_dict, size_dict = hypergraph_statistics(RT_data)

# %%
N, E, in_dict, out_dict, size_dict
# Out:
# (123,
#  446,
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 300, 3: 60, 1: 86}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {2: 313, 3: 52, 1: 81}),
#  defaultdict(<function useful_functions.hypergraph_statistics.<locals>.<lambda>()>,
#              {(2, 2): 222,
#               (2, 3): 46,
#               (3, 2): 54,
#               (2, 1): 32,
#               (1, 2): 37,
#               (1, 1): 43,
#               (1, 3): 6,
#               (3, 1): 6}))

# %%
fig, ax  = plt.subplots(1,3, figsize=(15,5))

ax[0].bar(in_dict.keys(), in_dict.values())

ax[1].bar(out_dict.keys(), out_dict.values())

ax[2].bar([str(size) for size in size_dict.keys()], size_dict.values())

ax[2].set_xticks(ax[2].get_xticks())
ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=90, ha='right')

plt.show()

# %% [markdown]
# ## Metabolical reactions

# %% [markdown]
# ### BiGG

# %% [markdown]
# Too many to display

# %%
folder = 'ParsedHyperedges/Metabolical-BiGG/'
for file in os.listdir(folder):
    
    with open(folder + file, 'rb') as f:
        BiGG_data = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 folder = 'ParsedHyperedges/Metabolical-BiGG/'
# ----> 2 for file in os.listdir(folder):
#       4     with open(folder + file, 'rb') as f:
#       5         BiGG_data = pickle.load(f)
#
# NameError: name 'os' is not defined
